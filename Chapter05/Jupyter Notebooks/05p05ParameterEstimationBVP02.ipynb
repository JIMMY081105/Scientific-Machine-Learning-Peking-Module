# %% [markdown]
# # 5.5 Another Inverse Problem for Boundary Value Problem

# %%
using CairoMakie
using LinearAlgebra
using LinearSolve
using SparseArrays
using BenchmarkTools
using CSV
using DataFrames

# %% [markdown]
# In this notebook, you are given that some data is taken from a beam deflection
#
# You are given some data points, which is the deflection, $y_i$ at each location $x_i$, $(x_i,y_i)$.  Your task is to find $w(x)$ that fits this data.
#
# As always, let's ready the  $(x_i,y_i)$ data points and see how they look like.

# %%
df = CSV.read("../Data01.csv", DataFrame;
select=["xdata", "ydata"])
xdata=df[:, :xdata]
ydata=df[:, :ydata]
# Out:
# 21-element Vector{Float64}:
#   6.193274031415785e-6
#  -0.003739378905905285
#  -0.007306349221306566
#  -0.010399180465463597
#  -0.013098308162873173
#  -0.01578551634224239
#  -0.01762495953731014
#  -0.019144283606991372
#  -0.020655809722303967
#  -0.021258175295570867
#   ⋮
#  -0.02035003021705797
#  -0.019230083080761153
#  -0.017536481088091162
#  -0.015780287203041334
#  -0.013109685125591448
#  -0.010249205411925406
#  -0.007305186584581027
#  -0.0037204446087818945
#  -3.915200830436959e-5

# %%
fig = Figure()
ax = Axis(fig[1, 1], xlabel = L"x", ylabel = L"y(x)")
scatter!(ax,xdata,ydata,color=:black,label="data")
axislegend(ax,position=:ct)
save("../figures/05p05ParameterEstimationBVP0201.svg",fig)
fig

# %% [markdown]
# Since we know that our data is taken from the deflection of a beam, can use what we know about the deflection of the beam.  From other parts of your degree program,  we know that a good model for the beam deflection is
#
# $\frac{d^2y}{dx^2}+4y(x)=w(x)$
#
#
# $y$ is the deflection of the beam and $w(x)$ a weight distribution on this beam.  The domain is $x\in [0,1]$. There is no deflection at the ends of the beam, so $y(0)=y(1)=0.0$.   We can discretise this equation as per usual
#
# $\frac{d^2y}{dx^2}\approx\frac{y_{i-1}-2y_i+y_{i+1}}{\Delta^2}$
#
# the governing equation for beam deflection becomes
#
# $\frac{y_{i-1}-2y_i+y_{i+1}}{\Delta^2}+4y_i=w(x_i)$
#
# We do not know what $w(x)$ is so we will just use a model and say
#
# $w(x)=a_0+a_1x$
#
# Our model becomes
#
# $\frac{y_{i-1}-2y_i+y_{i+1}}{\Delta^2}+4y_i=w(x_i)=a_0+a_1x_i$
#
# So our task now is to find $a_0$ and $a_1$ such that when you solve the the equation above, you get $y_i$ that agrees best agree with your data.

# %% [markdown]
# For a domain of 5 intervals, our matrix equations will look like
#
# $$
# \begin{bmatrix}
# 1 & 0 & 0 & 0 & 0 &0 \\
# 1/\Delta^2 & -2/\Delta^2+4 & 1/\Delta^2 & 0 & 0 & 0\\
# 0 & 1/\Delta^2 & -2/\Delta^2 +4& 1/\Delta^2 & 0 & 0 \\
# 0 &  0 & 1/\Delta^2 & -2/\Delta^2+4 & 1/\Delta^2 & 0  \\
# 0 &  0 & 0 & 1/\Delta^2 & -2/\Delta^2 +4& 1/\Delta^2   \\
# 0 &  0 & 0 & 0 & -1 & 1   \\
# \end{bmatrix}\begin{Bmatrix}
# y_1\\
# y_2\\
# y_3\\
# y_4\\
# y_5\\
# y_6\\
# \end{Bmatrix}=\begin{Bmatrix}
# 0\\
# a_0+a_1x_2\\
# a_0+a_1x_3\\
# a_0+a_1x_4\\
# a_0+a_1x_5\\
# 0\\
# \end{Bmatrix}
# $$

# %% [markdown]
# Everytime with want to make a prediction, we need to solve the equation above.  With the exception of $y_1$ and $y_6$, all your $y_i$'s above are dependent on $a_0$ and $a_1$. The dependence is not explicit but there is an implicit relationship.    In terms of a model, we can think of the above equations as an implicity definition of our $f_{model}(a_0,a_1,x)$
#
# $$
# \begin{bmatrix}
# 1 & 0 & 0 & 0 & 0 &0 \\
# 1/\Delta^2 & -2/\Delta^2+4 & 1/\Delta^2 & 0 & 0 & 0\\
# 0 & 1/\Delta^2 & -2/\Delta^2 +4& 1/\Delta^2 & 0 & 0 \\
# 0 &  0 & 1/\Delta^2 & -2/\Delta^2+4 & 1/\Delta^2 & 0  \\
# 0 &  0 & 0 & 1/\Delta^2 & -2/\Delta^2 +4& 1/\Delta^2   \\
# 0 &  0 & 0 & 0 & -1 & 1   \\
# \end{bmatrix}\begin{Bmatrix}
# f_{model}(a_0,a_1,x_1)\\
# f_{model}(a_0,a_1,x_2)\\
# f_{model}(a_0,a_1,x_3)\\
# f_{model}(a_0,a_1,x_4)\\
# f_{model}(a_0,a_1,x_5)\\
# f_{model}(a_0,a_1,x_6)\\
# \end{Bmatrix}=\begin{Bmatrix}
# 0\\
# a_0+a_1x_2\\
# a_0+a_1x_3\\
# a_0+a_1x_4\\
# a_0+a_1x_5\\
# 0\\
# \end{Bmatrix}
# $$

# %% [markdown]
# Set up matrices

# %%
Delta=xdata[2]-xdata[1]
n=length(xdata)
d=zeros(n)
dl=zeros(n-1)
du=zeros(n-1)
C=zeros(n)
du[1]=0.0
d[1]=1.0
C[1]=0.0
for i=2:n-1
    dl[i-1]=(1.0/Delta^2)
    d[i]=-(2.0/Delta^2)+4.0
    du[i]=(1.0/Delta^2)
end
dl[n-1]=0.0
d[n]=1.0
C[n]=0.0

# Construct the specialized structured matrix
A = Tridiagonal(dl, d, du)
# Out:
# 21×21 Tridiagonal{Float64, Vector{Float64}}:
#    1.0     0.0      ⋅       ⋅       ⋅   …      ⋅       ⋅       ⋅      ⋅
#  400.0  -796.0   400.0      ⋅       ⋅          ⋅       ⋅       ⋅      ⋅
#     ⋅    400.0  -796.0   400.0      ⋅          ⋅       ⋅       ⋅      ⋅
#     ⋅       ⋅    400.0  -796.0   400.0         ⋅       ⋅       ⋅      ⋅
#     ⋅       ⋅       ⋅    400.0  -796.0         ⋅       ⋅       ⋅      ⋅
#     ⋅       ⋅       ⋅       ⋅    400.0  …      ⋅       ⋅       ⋅      ⋅
#     ⋅       ⋅       ⋅       ⋅       ⋅          ⋅       ⋅       ⋅      ⋅
#     ⋅       ⋅       ⋅       ⋅       ⋅          ⋅       ⋅       ⋅      ⋅
#     ⋅       ⋅       ⋅       ⋅       ⋅          ⋅       ⋅       ⋅      ⋅
#     ⋅       ⋅       ⋅       ⋅       ⋅          ⋅       ⋅       ⋅      ⋅
#    ⋮                                    ⋱                            ⋮
#     ⋅       ⋅       ⋅       ⋅       ⋅          ⋅       ⋅       ⋅      ⋅
#     ⋅       ⋅       ⋅       ⋅       ⋅          ⋅       ⋅       ⋅      ⋅
#     ⋅       ⋅       ⋅       ⋅       ⋅          ⋅       ⋅       ⋅      ⋅
#     ⋅       ⋅       ⋅       ⋅       ⋅   …      ⋅       ⋅       ⋅      ⋅
#     ⋅       ⋅       ⋅       ⋅       ⋅       400.0      ⋅       ⋅      ⋅
#     ⋅       ⋅       ⋅       ⋅       ⋅      -796.0   400.0      ⋅      ⋅
#     ⋅       ⋅       ⋅       ⋅       ⋅       400.0  -796.0   400.0     ⋅
#     ⋅       ⋅       ⋅       ⋅       ⋅          ⋅    400.0  -796.0  400.0
#     ⋅       ⋅       ⋅       ⋅       ⋅   …      ⋅       ⋅      0.0    1.0

# %%
function loss(p,ydata)
    
    C=(p[1].+p[2]*xdata) #this is the model for  w(x)
    C[1]=0.0
    C[n]=0.0
    prob=LinearProblem(A,C)
    fmodel=LinearSolve.solve(prob)

    return sum(0.5*(fmodel.-ydata).^2)
end
# Out:
# loss (generic function with 1 method)

# %%
function callback(state, l)
    push!(losses, l)
    if length(losses) % 50 == 0
        println("Current loss after $(length(losses)) iterations: $(losses[end])")
    end
    return false
end
# Out:
# callback (generic function with 1 method)

# %%
using Optimization
using Optimisers
using OptimizationOptimisers
using ForwardDiff

losses = Float64[]
adtype = AutoForwardDiff()
optf = OptimizationFunction(loss, adtype)
optprob = OptimizationProblem(optf,[1.0,1.0],ydata)
sol=Optimization.solve(optprob,Adam(0.001f0),maxiters=50000, callback=callback)
# Out:
# Current loss after 50 iterations: 0.4159506366936311
# Current loss after 100 iterations: 0.37160558592396
# Current loss after 150 iterations: 0.3309155298329799
# Current loss after 200 iterations: 0.29368779452999194
# Current loss after 250 iterations: 0.259729987851196
# Current loss after 300 iterations: 0.2288530396570117
# Current loss after 350 iterations: 0.20087131958566437
# Current loss after 400 iterations: 0.17560279645712396
# Current loss after 450 iterations: 0.1528692446764662
# Current loss after 500 iterations: 0.13249649078900783
# Current loss after 550 iterations: 0.11431469616493299
# Current loss after 600 iterations: 0.09815867177414851
# Current loss after 650 iterations: 0.08386822006508764
# Current loss after 700 iterations: 0.07128849765892703
# Current loss after 750 iterations: 0.06027039113943556
# Current loss after 800 iterations: 0.050670896798267244
# Current loss after 850 iterations: 0.042353493907833155
# Current loss after 900 iterations: 0.03518850006014185
# Current loss after 950 iterations: 0.029053396450528304
# Current loss after 1000 iterations: 0.02383311081213822
# Current loss after 1050 iterations: 0.019420246112682303
# Current loss after 1100 iterations: 0.015715244169201042
# Current loss after 1150 iterations: 0.01262647503453275
# Current loss after 1200 iterations: 0.010070245322259632
# Current loss after 1250 iterations: 0.007970721468579486
# Current loss after 1300 iterations: 0.0062597671281219335
# Current loss after 1350 iterations: 0.004876697269372476
# Current loss after 1400 iterations: 0.003767954849197863
# Current loss after 1450 iterations: 0.0028867189741705623
# Current loss after 1500 iterations: 0.002192455986580525
# Current loss after 1550 iterations: 0.0016504267741969745
# Current loss after 1600 iterations: 0.001231164683589851
# Current loss after 1650 iterations: 0.000909938675891837
# Current loss after 1700 iterations: 0.0006662158318492129
# Current loss after 1750 iterations: 0.00048313608498369223
# Current loss after 1800 iterations: 0.00034701028282646274
# Current loss after 1850 iterations: 0.00024685052247419017
# Current loss after 1900 iterations: 0.00017393936429320797
# Current loss after 1950 iterations: 0.0001214421734537731
# Current loss after 2000 iterations: 8.406462547893271e-5
# Current loss after 2050 iterations: 5.775545653594821e-5
# Current loss after 2100 iterations: 3.94529194293368e-5
# Current loss after 2150 iterations: 2.687216037380037e-5
# Current loss after 2200 iterations: 1.8329862710328723e-5
# Current loss after 2250 iterations: 1.2601986695817394e-5
# Current loss after 2300 iterations: 8.810224322110682e-6
# Current loss after 2350 iterations: 6.332828103706831e-6
# Current loss after 2400 iterations: 4.735701940657206e-6
# Current loss after 2450 iterations: 3.7200012452511047e-6
# Current loss after 2500 iterations: 3.082925257807382e-6
# Current loss after 2550 iterations: 2.6888522579058582e-6
# Current loss after 2600 iterations: 2.4484334091010062e-6
# Current loss after 2650 iterations: 2.3036982693425224e-6
# Current loss after 2700 iterations: 2.217618517148223e-6
# Current loss after 2750 iterations: 2.1669177195615654e-6
# Current loss after 2800 iterations: 2.137201495678703e-6
# Current loss after 2850 iterations: 2.11971603058626e-6
# Current loss after 2900 iterations: 2.109228226441823e-6
# Current loss after 2950 iterations: 2.1026640756149265e-6
# Current loss after 3000 iterations: 2.0982499350619334e-6
# Current loss after 3050 iterations: 2.0949809887661052e-6
# Current loss after 3100 iterations: 2.092298452961328e-6
# Current loss after 3150 iterations: 2.0898973326455765e-6
# Current loss after 3200 iterations: 2.0876141890418526e-6
# Current loss after 3250 iterations: 2.0853629407154563e-6
# Current loss after 3300 iterations: 2.083098899665848e-6
# Current loss after 3350 iterations: 2.0807990508889037e-6
# Current loss after 3400 iterations: 2.078451473336492e-6
# Current loss after 3450 iterations: 2.0760497909125853e-6
# Current loss after 3500 iterations: 2.0735903281599575e-6
# Current loss after 3550 iterations: 2.0710706863706613e-6
# Current loss after 3600 iterations: 2.0684890478294053e-6
# Current loss after 3650 iterations: 2.0658438441559083e-6
# Current loss after 3700 iterations: 2.0631336021411753e-6
# Current loss after 3750 iterations: 2.060356873898978e-6
# Current loss after 3800 iterations: 2.05751220597931e-6
# Current loss after 3850 iterations: 2.054598126036321e-6
# Current loss after 3900 iterations: 2.051613137162258e-6
# Current loss after 3950 iterations: 2.0485557154913614e-6
# Current loss after 4000 iterations: 2.045424309162863e-6
# Current loss after 4050 iterations: 2.0422173378361988e-6
# Current loss after 4100 iterations: 2.0389331924272534e-6
# Current loss after 4150 iterations: 2.035570234951974e-6
# Current loss after 4200 iterations: 2.0321267984134033e-6
# Current loss after 4250 iterations: 2.028601186720883e-6
# Current loss after 4300 iterations: 2.024991674645318e-6
# Current loss after 4350 iterations: 2.021296507794645e-6
# Current loss after 4400 iterations: 2.01751390262577e-6
# Current loss after 4450 iterations: 2.013642046481964e-6
# Current loss after 4500 iterations: 2.009679097663586e-6
# Current loss after 4550 iterations: 2.0056231855439112e-6
# Current loss after 4600 iterations: 2.0014724107079195e-6
# Current loss after 4650 iterations: 1.9972248451380434e-6
# Current loss after 4700 iterations: 1.992878532447623e-6
# Current loss after 4750 iterations: 1.988431488148372e-6
# Current loss after 4800 iterations: 1.9838816999732175e-6
# Current loss after 4850 iterations: 1.979227128244644e-6
# Current loss after 4900 iterations: 1.9744657063011852e-6
# Current loss after 4950 iterations: 1.9695953409722293e-6
# Current loss after 5000 iterations: 1.964613913120067e-6
# Current loss after 5050 iterations: 1.9595192782380047e-6
# Current loss after 5100 iterations: 1.954309267114796e-6
# Current loss after 5150 iterations: 1.948981686570226e-6
# Current loss after 5200 iterations: 1.943534320261946e-6
# Current loss after 5250 iterations: 1.937964929561618e-6
# Current loss after 5300 iterations: 1.932271254522951e-6
# Current loss after 5350 iterations: 1.9264510149190774e-6
# Current loss after 5400 iterations: 1.920501911377711e-6
# Current loss after 5450 iterations: 1.9144216265984145e-6
# Current loss after 5500 iterations: 1.9082078266714447e-6
# Current loss after 5550 iterations: 1.9018581624921346e-6
# Current loss after 5600 iterations: 1.8953702712790674e-6
# Current loss after 5650 iterations: 1.8887417781995658e-6
# Current loss after 5700 iterations: 1.8819702981097477e-6
# Current loss after 5750 iterations: 1.8750534374064035e-6
# Current loss after 5800 iterations: 1.8679887960045146e-6
# Current loss after 5850 iterations: 1.8607739694375175e-6
# Current loss after 5900 iterations: 1.8534065510891846e-6
# Current loss after 5950 iterations: 1.8458841345615867e-6
# Current loss after 6000 iterations: 1.8382043161804252e-6
# Current loss after 6050 iterations: 1.8303646976462589e-6
# Current loss after 6100 iterations: 1.8223628888357123e-6
# Current loss after 6150 iterations: 1.8141965107580396e-6
# Current loss after 6200 iterations: 1.805863198667408e-6
# Current loss after 6250 iterations: 1.7973606053382936e-6
# Current loss after 6300 iterations: 1.7886864045173395e-6
# Current loss after 6350 iterations: 1.779838294537172e-6
# Current loss after 6400 iterations: 1.7708140021141167e-6
# Current loss after 6450 iterations: 1.7616112863269525e-6
# Current loss after 6500 iterations: 1.7522279427796102e-6
# Current loss after 6550 iterations: 1.7426618079564907e-6
# Current loss after 6600 iterations: 1.7329107637648177e-6
# Current loss after 6650 iterations: 1.7229727422863116e-6
# Current loss after 6700 iterations: 1.7128457307150548e-6
# Current loss after 6750 iterations: 1.7025277765088948e-6
# Current loss after 6800 iterations: 1.6920169927400204e-6
# Current loss after 6850 iterations: 1.6813115636607442e-6
# Current loss after 6900 iterations: 1.6704097504670647e-6
# Current loss after 6950 iterations: 1.6593098972865906e-6
# Current loss after 7000 iterations: 1.648010437366483e-6
# Current loss after 7050 iterations: 1.636509899477586e-6
# Current loss after 7100 iterations: 1.6248069145307277e-6
# Current loss after 7150 iterations: 1.6129002223931637e-6
# Current loss after 7200 iterations: 1.600788678924189e-6
# Current loss after 7250 iterations: 1.5884712632022255e-6
# Current loss after 7300 iterations: 1.5759470849613366e-6
# Current loss after 7350 iterations: 1.5632153922133757e-6
# Current loss after 7400 iterations: 1.5502755790650661e-6
# Current loss after 7450 iterations: 1.5371271937132713e-6
# Current loss after 7500 iterations: 1.523769946612464e-6
# Current loss after 7550 iterations: 1.5102037188026894e-6
# Current loss after 7600 iterations: 1.4964285703976617e-6
# Current loss after 7650 iterations: 1.4824447491984725e-6
# Current loss after 7700 iterations: 1.4682526994439459e-6
# Current loss after 7750 iterations: 1.4538530706607092e-6
# Current loss after 7800 iterations: 1.4392467266095444e-6
# Current loss after 7850 iterations: 1.4244347543037627e-6
# Current loss after 7900 iterations: 1.4094184730705894e-6
# Current loss after 7950 iterations: 1.3941994436511603e-6
# Current loss after 8000 iterations: 1.3787794772921002e-6
# Current loss after 8050 iterations: 1.3631606448161483e-6
# Current loss after 8100 iterations: 1.3473452856400753e-6
# Current loss after 8150 iterations: 1.3313360166996275e-6
# Current loss after 8200 iterations: 1.3151357412588375e-6
# Current loss after 8250 iterations: 1.2987476575591166e-6
# Current loss after 8300 iterations: 1.2821752672733296e-6
# Current loss after 8350 iterations: 1.2654223837230597e-6
# Current loss after 8400 iterations: 1.248493139812402e-6
# Current loss after 8450 iterations: 1.2313919956386707e-6
# Current loss after 8500 iterations: 1.2141237457247724e-6
# Current loss after 8550 iterations: 1.1966935258249964e-6
# Current loss after 8600 iterations: 1.1791068192551932e-6
# Current loss after 8650 iterations: 1.161369462684522e-6
# Current loss after 8700 iterations: 1.1434876513361e-6
# Current loss after 8750 iterations: 1.1254679435381225e-6
# Current loss after 8800 iterations: 1.107317264557081e-6
# Current loss after 8850 iterations: 1.0890429096616413e-6
# Current loss after 8900 iterations: 1.070652546338806e-6
# Current loss after 8950 iterations: 1.052154215607082e-6
# Current loss after 9000 iterations: 1.0335563323560636e-6
# Current loss after 9050 iterations: 1.014867684641892e-6
# Current loss after 9100 iterations: 9.960974318760565e-7
# Current loss after 9150 iterations: 9.7725510183706e-7
# Current loss after 9200 iterations: 9.583505864346163e-7
# Current loss after 9250 iterations: 9.393941361654825e-7
# Current loss after 9300 iterations: 9.203963531904021e-7
# Current loss after 9350 iterations: 9.013681829747398e-7
# Current loss after 9400 iterations: 8.823209044248972e-7
# Current loss after 9450 iterations: 8.632661184715198e-7
# Current loss after 9500 iterations: 8.442157350362933e-7
# Current loss after 9550 iterations: 8.251819583449295e-7
# Current loss after 9600 iterations: 8.06177270532491e-7
# Current loss after 9650 iterations: 7.872144135068558e-7
# Current loss after 9700 iterations: 7.683063690459769e-7
# Current loss after 9750 iterations: 7.494663370941579e-7
# Current loss after 9800 iterations: 7.307077122547173e-7
# Current loss after 9850 iterations: 7.120440584660009e-7
# Current loss after 9900 iterations: 6.934890818712369e-7
# Current loss after 9950 iterations: 6.750566019000031e-7
# Current loss after 10000 iterations: 6.567605205813243e-7
# Current loss after 10050 iterations: 6.386147901460195e-7
# Current loss after 10100 iterations: 6.20633378955802e-7
# Current loss after 10150 iterations: 6.02830235843598e-7
# Current loss after 10200 iterations: 5.852192529444684e-7
# Current loss after 10250 iterations: 5.678142271153051e-7
# Current loss after 10300 iterations: 5.506288200673471e-7
# Current loss after 10350 iterations: 5.336765173398156e-7
# Current loss after 10400 iterations: 5.16970586267577e-7
# Current loss after 10450 iterations: 5.005240331126834e-7
# Current loss after 10500 iterations: 4.843495595406575e-7
# Current loss after 10550 iterations: 4.6845951864898584e-7
# Current loss after 10600 iterations: 4.5286587076196136e-7
# Current loss after 10650 iterations: 4.375801392298313e-7
# Current loss after 10700 iterations: 4.22613366478354e-7
# Current loss after 10750 iterations: 4.079760705788916e-7
# Current loss after 10800 iterations: 3.9367820260776573e-7
# Current loss after 10850 iterations: 3.7972910508987746e-7
# Current loss after 10900 iterations: 3.6613747182015363e-7
# Current loss after 10950 iterations: 3.529113093684976e-7
# Current loss after 11000 iterations: 3.4005790057865733e-7
# Current loss after 11050 iterations: 3.2758377037192813e-7
# Current loss after 11100 iterations: 3.15494654169687e-7
# Current loss after 11150 iterations: 3.037954692388313e-7
# Current loss after 11200 iterations: 2.9249028926553375e-7
# Current loss after 11250 iterations: 2.815823224454656e-7
# Current loss after 11300 iterations: 2.7107389336664614e-7
# Current loss after 11350 iterations: 2.6096642894684493e-7
# Current loss after 11400 iterations: 2.5126044865704936e-7
# Current loss after 11450 iterations: 2.419555592482662e-7
# Current loss after 11500 iterations: 2.3305045415700697e-7
# Current loss after 11550 iterations: 2.24542917743944e-7
# Current loss after 11600 iterations: 2.1642983447145266e-7
# Current loss after 11650 iterations: 2.0870720309446113e-7
# Current loss after 11700 iterations: 2.0137015589285925e-7
# Current loss after 11750 iterations: 1.9441298292245215e-7
# Current loss after 11800 iterations: 1.8782916122320174e-7
# Current loss after 11850 iterations: 1.816113888640769e-7
# Current loss after 11900 iterations: 1.757516236582519e-7
# Current loss after 11950 iterations: 1.7024112632876147e-7
# Current loss after 12000 iterations: 1.6507050785289404e-7
# Current loss after 12050 iterations: 1.6022978066545155e-7
# Current loss after 12100 iterations: 1.5570841335109709e-7
# Current loss after 12150 iterations: 1.5149538840950332e-7
# Current loss after 12200 iterations: 1.4757926263801608e-7
# Current loss after 12250 iterations: 1.4394822963506043e-7
# Current loss after 12300 iterations: 1.4059018389901302e-7
# Current loss after 12350 iterations: 1.3749278596698204e-7
# Current loss after 12400 iterations: 1.3464352802120328e-7
# Current loss after 12450 iterations: 1.3202979937726896e-7
# Current loss after 12500 iterations: 1.2963895126293046e-7
# Current loss after 12550 iterations: 1.2745836030188652e-7
# Current loss after 12600 iterations: 1.254754901269067e-7
# Current loss after 12650 iterations: 1.2367795056935822e-7
# Current loss after 12700 iterations: 1.2205355389927273e-7
# Current loss after 12750 iterations: 1.2059036762939234e-7
# Current loss after 12800 iterations: 1.1927676343964015e-7
# Current loss after 12850 iterations: 1.1810146183283718e-7
# Current loss after 12900 iterations: 1.1705357218856514e-7
# Current loss after 12950 iterations: 1.1612262794774134e-7
# Current loss after 13000 iterations: 1.1529861672730173e-7
# Current loss after 13050 iterations: 1.1457200523549421e-7
# Current loss after 13100 iterations: 1.1393375893099412e-7
# Current loss after 13150 iterations: 1.1337535644153267e-7
# Current loss after 13200 iterations: 1.1288879882874795e-7
# Current loss after 13250 iterations: 1.124666138554601e-7
# Current loss after 13300 iterations: 1.1210185547518748e-7
# Current loss after 13350 iterations: 1.1178809882356878e-7
# Current loss after 13400 iterations: 1.1151943104372065e-7
# Current loss after 13450 iterations: 1.1129043832241017e-7
# Current loss after 13500 iterations: 1.1109618955082427e-7
# Current loss after 13550 iterations: 1.1093221705075082e-7
# Current loss after 13600 iterations: 1.1079449482584738e-7
# Current loss after 13650 iterations: 1.106794148056274e-7
# Current loss after 13700 iterations: 1.105837615495817e-7
# Current loss after 13750 iterations: 1.105046858689506e-7
# Current loss after 13800 iterations: 1.1043967780547338e-7
# Current loss after 13850 iterations: 1.1038653938152721e-7
# Current loss after 13900 iterations: 1.1034335750274325e-7
# Current loss after 13950 iterations: 1.1030847735814834e-7
# Current loss after 14000 iterations: 1.1028047662034697e-7
# Current loss after 14050 iterations: 1.1025814070398021e-7
# Current loss after 14100 iterations: 1.1024043929520928e-7
# Current loss after 14150 iterations: 1.1022650431851549e-7
# Current loss after 14200 iterations: 1.1021560946215904e-7
# Current loss after 14250 iterations: 1.1020715134059558e-7
# Current loss after 14300 iterations: 1.1020063233206558e-7
# Current loss after 14350 iterations: 1.1019564509374403e-7
# Current loss after 14400 iterations: 1.1019185872421373e-7
# Current loss after 14450 iterations: 1.1018900651718866e-7
# Current loss after 14500 iterations: 1.1018687522688916e-7
# Current loss after 14550 iterations: 1.1018529574960169e-7
# Current loss after 14600 iterations: 1.1018413511270107e-7
# Current loss after 14650 iterations: 1.1018328965522995e-7
# Current loss after 14700 iterations: 1.1018267928004094e-7
# Current loss after 14750 iterations: 1.1018224265762364e-7
# Current loss after 14800 iterations: 1.1018193326468788e-7
# Current loss after 14850 iterations: 1.1018171614552729e-7
# Current loss after 14900 iterations: 1.1018156529257964e-7
# Current loss after 14950 iterations: 1.1018146154952352e-7
# Current loss after 15000 iterations: 1.101813909517026e-7
# Current loss after 15050 iterations: 1.1018134342635389e-7
# Current loss after 15100 iterations: 1.1018131178675028e-7
# Current loss after 15150 iterations: 1.1018129096227119e-7
# Current loss after 15200 iterations: 1.1018127741603024e-7
# Current loss after 15250 iterations: 1.1018126870992047e-7
# Current loss after 15300 iterations: 1.1018126318354845e-7
# Current loss after 15350 iterations: 1.1018125972001261e-7
# Current loss after 15400 iterations: 1.1018125757757556e-7
# Current loss after 15450 iterations: 1.1018125627008764e-7
# Current loss after 15500 iterations: 1.1018125548311783e-7
# Current loss after 15550 iterations: 1.1018125501614798e-7
# Current loss after 15600 iterations: 1.1018125474309678e-7
# Current loss after 15650 iterations: 1.1018125458583634e-7
# Current loss after 15700 iterations: 1.1018125449663176e-7
# Current loss after 15750 iterations: 1.101812544468447e-7
# Current loss after 15800 iterations: 1.1018125441951131e-7
# Current loss after 15850 iterations: 1.1018125440474025e-7
# Current loss after 15900 iterations: 1.1018125439691013e-7
# Current loss after 15950 iterations: 1.1018125439282104e-7
# Current loss after 16000 iterations: 1.1018125439073109e-7
# Current loss after 16050 iterations: 1.1018125438969066e-7
# Current loss after 16100 iterations: 1.1018125438916367e-7
# Current loss after 16150 iterations: 1.10181254388918e-7
# Current loss after 16200 iterations: 1.1018125438880553e-7
# Current loss after 16250 iterations: 1.1018125438875744e-7
# Current loss after 16300 iterations: 1.1018125438871825e-7
# Current loss after 16350 iterations: 1.1018125438869866e-7
# Current loss after 16400 iterations: 1.1018125438872403e-7
# Current loss after 16450 iterations: 1.1018125438870155e-7
# Current loss after 16500 iterations: 1.1018125438869384e-7
# Current loss after 16550 iterations: 1.1018125438869927e-7
# Current loss after 16600 iterations: 1.1018125438872423e-7
# Current loss after 16650 iterations: 1.10181254388713e-7
# Current loss after 16700 iterations: 1.1018125438870544e-7
# Current loss after 16750 iterations: 1.1018125438868923e-7
# Current loss after 16800 iterations: 1.1018125438872189e-7
# Current loss after 16850 iterations: 1.1018125438869615e-7
# Current loss after 16900 iterations: 1.1018125438868998e-7
# Current loss after 16950 iterations: 1.101812543886928e-7
# Current loss after 17000 iterations: 1.1018125438870306e-7
# Current loss after 17050 iterations: 1.1018125438868827e-7
# Current loss after 17100 iterations: 1.1018125438870337e-7
# Current loss after 17150 iterations: 1.1018125438869301e-7
# Current loss after 17200 iterations: 1.101812543887057e-7
# Current loss after 17250 iterations: 1.101812543887134e-7
# Current loss after 17300 iterations: 1.1018125438868375e-7
# Current loss after 17350 iterations: 1.1018125438870617e-7
# Current loss after 17400 iterations: 1.1018125438871509e-7
# Current loss after 17450 iterations: 1.1018125438869746e-7
# Current loss after 17500 iterations: 1.1018125438871536e-7
# Current loss after 17550 iterations: 1.1018125438869153e-7
# Current loss after 17600 iterations: 1.1018125438870217e-7
# Current loss after 17650 iterations: 1.1018125438871306e-7
# Current loss after 17700 iterations: 1.10181254388701e-7
# Current loss after 17750 iterations: 1.1018125438870233e-7
# Current loss after 17800 iterations: 1.1018125438870979e-7
# Current loss after 17850 iterations: 1.1018125438869044e-7
# Current loss after 17900 iterations: 1.1018125438870411e-7
# Current loss after 17950 iterations: 1.1018125438869653e-7
# Current loss after 18000 iterations: 1.1018125438871125e-7
# Current loss after 18050 iterations: 1.1018125438869707e-7
# Current loss after 18100 iterations: 1.1018125438869844e-7
# Current loss after 18150 iterations: 1.1018125438870368e-7
# Current loss after 18200 iterations: 1.101812543886905e-7
# Current loss after 18250 iterations: 1.1018125438869044e-7
# Current loss after 18300 iterations: 1.1018125438870655e-7
# Current loss after 18350 iterations: 1.1018125438871912e-7
# Current loss after 18400 iterations: 1.1018125438871351e-7
# Current loss after 18450 iterations: 1.1018125438869342e-7
# Current loss after 18500 iterations: 1.1018125438869044e-7
# Current loss after 18550 iterations: 1.1018125438871354e-7
# Current loss after 18600 iterations: 1.1018125438870752e-7
# Current loss after 18650 iterations: 1.1018125438869836e-7
# Current loss after 18700 iterations: 1.1018125438870897e-7
# Current loss after 18750 iterations: 1.1018125438872012e-7
# Current loss after 18800 iterations: 1.1018125438870287e-7
# Current loss after 18850 iterations: 1.1018125438872553e-7
# Current loss after 18900 iterations: 1.1018125438870253e-7
# Current loss after 18950 iterations: 1.1018125438871052e-7
# Current loss after 19000 iterations: 1.1018125438870946e-7
# Current loss after 19050 iterations: 1.1018125438870603e-7
# Current loss after 19100 iterations: 1.1018125438869989e-7
# Current loss after 19150 iterations: 1.1018125438870881e-7
# Current loss after 19200 iterations: 1.1018125438871789e-7
# Current loss after 19250 iterations: 1.1018125438871214e-7
# Current loss after 19300 iterations: 1.1018125438869318e-7
# Current loss after 19350 iterations: 1.1018125438871583e-7
# Current loss after 19400 iterations: 1.1018125438868757e-7
# Current loss after 19450 iterations: 1.1018125438872223e-7
# Current loss after 19500 iterations: 1.1018125438870863e-7
# Current loss after 19550 iterations: 1.1018125438870082e-7
# Current loss after 19600 iterations: 1.1018125438871214e-7
# Current loss after 19650 iterations: 1.1018125438869731e-7
# Current loss after 19700 iterations: 1.101812543886917e-7
# Current loss after 19750 iterations: 1.1018125438872054e-7
# Current loss after 19800 iterations: 1.1018125438869923e-7
# Current loss after 19850 iterations: 1.1018125438869848e-7
# Current loss after 19900 iterations: 1.1018125438871128e-7
# Current loss after 19950 iterations: 1.1018125438868807e-7
# Current loss after 20000 iterations: 1.1018125438870111e-7
# Current loss after 20050 iterations: 1.1018125438871789e-7
# Current loss after 20100 iterations: 1.1018125438870136e-7
# Current loss after 20150 iterations: 1.1018125438869685e-7
# Current loss after 20200 iterations: 1.1018125438871466e-7
# Current loss after 20250 iterations: 1.1018125438871286e-7
# Current loss after 20300 iterations: 1.1018125438870008e-7
# Current loss after 20350 iterations: 1.1018125438869611e-7
# Current loss after 20400 iterations: 1.1018125438879996e-7
# Current loss after 20450 iterations: 1.1272643897589199e-7
# Current loss after 20500 iterations: 1.1022330790381405e-7
# Current loss after 20550 iterations: 1.1018125597718383e-7
# Current loss after 20600 iterations: 1.1018125552703377e-7
# Current loss after 20650 iterations: 1.1018125439606885e-7
# Current loss after 20700 iterations: 1.1018125438868998e-7
# Current loss after 20750 iterations: 1.1018125438871157e-7
# Current loss after 20800 iterations: 1.1018125438870314e-7
# Current loss after 20850 iterations: 1.1018125438869523e-7
# Current loss after 20900 iterations: 1.1018125438867484e-7
# Current loss after 20950 iterations: 1.1018125438870009e-7
# Current loss after 21000 iterations: 1.1330727036990838e-7
# Current loss after 21050 iterations: 1.1039127984963591e-7
# Current loss after 21100 iterations: 1.1018170293026696e-7
# Current loss after 21150 iterations: 1.1018125575564904e-7
# Current loss after 21200 iterations: 1.1018125443145156e-7
# Current loss after 21250 iterations: 1.1018125438873182e-7
# Current loss after 21300 iterations: 1.1018125438870664e-7
# Current loss after 21350 iterations: 1.1018125438870312e-7
# Current loss after 21400 iterations: 1.1018125438871715e-7
# Current loss after 21450 iterations: 1.101812543887104e-7
# Current loss after 21500 iterations: 1.1018125438870495e-7
# Current loss after 21550 iterations: 1.3941265781232975e-7
# Current loss after 21600 iterations: 1.103409531767006e-7
# Current loss after 21650 iterations: 1.1018169045936751e-7
# Current loss after 21700 iterations: 1.1018125521333235e-7
# Current loss after 21750 iterations: 1.1018125441778808e-7
# Current loss after 21800 iterations: 1.1018125438880101e-7
# Current loss after 21850 iterations: 1.1018125438872847e-7
# Current loss after 21900 iterations: 1.101812543887116e-7
# Current loss after 21950 iterations: 1.1018125438871577e-7
# Current loss after 22000 iterations: 1.101812543887018e-7
# Current loss after 22050 iterations: 1.101812544027438e-7
# Current loss after 22100 iterations: 1.1426584281747419e-7
# Current loss after 22150 iterations: 1.1018165212452153e-7
# Current loss after 22200 iterations: 1.1018133279428922e-7
# Current loss after 22250 iterations: 1.101812550760763e-7
# Current loss after 22300 iterations: 1.1018125438871067e-7
# Current loss after 22350 iterations: 1.1018125438871833e-7
# Current loss after 22400 iterations: 1.1018125438871228e-7
# Current loss after 22450 iterations: 1.1018125438871088e-7
# Current loss after 22500 iterations: 1.1018125438871517e-7
# Current loss after 22550 iterations: 1.101812543887238e-7
# Current loss after 22600 iterations: 1.1083794787070639e-7
# Current loss after 22650 iterations: 1.10199829872829e-7
# Current loss after 22700 iterations: 1.1018128957671349e-7
# Current loss after 22750 iterations: 1.1018125626785653e-7
# Current loss after 22800 iterations: 1.1018125440624434e-7
# Current loss after 22850 iterations: 1.1018125438870458e-7
# Current loss after 22900 iterations: 1.1018125438871302e-7
# Current loss after 22950 iterations: 1.1018125438870613e-7
# Current loss after 23000 iterations: 1.1018125438871048e-7
# Current loss after 23050 iterations: 1.1018125438870775e-7
# Current loss after 23100 iterations: 1.4029240465581664e-7
# Current loss after 23150 iterations: 1.102107174921522e-7
# Current loss after 23200 iterations: 1.101816324226546e-7
# Current loss after 23250 iterations: 1.1018125744825723e-7
# Current loss after 23300 iterations: 1.1018125439559858e-7
# Current loss after 23350 iterations: 1.1018125438871337e-7
# Current loss after 23400 iterations: 1.1018125438871959e-7
# Current loss after 23450 iterations: 1.1018125438868559e-7
# Current loss after 23500 iterations: 1.1018125438869173e-7
# Current loss after 23550 iterations: 1.101812543887215e-7
# Current loss after 23600 iterations: 1.1102511808830106e-7
# Current loss after 23650 iterations: 1.1021317192031713e-7
# Current loss after 23700 iterations: 1.1018126174364845e-7
# Current loss after 23750 iterations: 1.1018125471226631e-7
# Current loss after 23800 iterations: 1.1018125439927886e-7
# Current loss after 23850 iterations: 1.1018125438870601e-7
# Current loss after 23900 iterations: 1.1018125438869715e-7
# Current loss after 23950 iterations: 1.1018125438871419e-7
# Current loss after 24000 iterations: 1.1018125438870934e-7
# Current loss after 24050 iterations: 1.1018125438869359e-7
# Current loss after 24100 iterations: 1.1744431692684959e-7
# Current loss after 24150 iterations: 1.1035389479442326e-7
# Current loss after 24200 iterations: 1.1018182749754774e-7
# Current loss after 24250 iterations: 1.1018125583535517e-7
# Current loss after 24300 iterations: 1.1018125438869664e-7
# Current loss after 24350 iterations: 1.1018125438885876e-7
# Current loss after 24400 iterations: 1.1018125438871273e-7
# Current loss after 24450 iterations: 1.101812543887007e-7
# Current loss after 24500 iterations: 1.101812543886915e-7
# Current loss after 24550 iterations: 1.1018125438872276e-7
# Current loss after 24600 iterations: 1.1251882926493115e-7
# Current loss after 24650 iterations: 1.102561109701873e-7
# Current loss after 24700 iterations: 1.1018250016259138e-7
# Current loss after 24750 iterations: 1.101812574968944e-7
# Current loss after 24800 iterations: 1.101812543953877e-7
# Current loss after 24850 iterations: 1.1018125438883519e-7
# Current loss after 24900 iterations: 1.1018125438870507e-7
# Current loss after 24950 iterations: 1.1018125438869674e-7
# Current loss after 25000 iterations: 1.101812543887177e-7
# Current loss after 25050 iterations: 1.1018125438880548e-7
# Current loss after 25100 iterations: 1.2211817467241547e-7
# Current loss after 25150 iterations: 1.1024668489220511e-7
# Current loss after 25200 iterations: 1.1018150988043103e-7
# Current loss after 25250 iterations: 1.1018125443391091e-7
# Current loss after 25300 iterations: 1.1018125438926017e-7
# Current loss after 25350 iterations: 1.1018125438870705e-7
# Current loss after 25400 iterations: 1.10181254388691e-7
# Current loss after 25450 iterations: 1.1018125438870703e-7
# Current loss after 25500 iterations: 1.1018125438869894e-7
# Current loss after 25550 iterations: 1.1018129169768669e-7
# Current loss after 25600 iterations: 1.1110993262238877e-7
# Current loss after 25650 iterations: 1.1018150882446429e-7
# Current loss after 25700 iterations: 1.1018126368464408e-7
# Current loss after 25750 iterations: 1.101812546009887e-7
# Current loss after 25800 iterations: 1.1018125438869502e-7
# Current loss after 25850 iterations: 1.1018125438869836e-7
# Current loss after 25900 iterations: 1.1018125438871667e-7
# Current loss after 25950 iterations: 1.1018125438869514e-7
# Current loss after 26000 iterations: 1.1018125438883053e-7
# Current loss after 26050 iterations: 1.2268260579739932e-7
# Current loss after 26100 iterations: 1.1020170196032377e-7
# Current loss after 26150 iterations: 1.1018143978024735e-7
# Current loss after 26200 iterations: 1.1018125553620149e-7
# Current loss after 26250 iterations: 1.1018125438985568e-7
# Current loss after 26300 iterations: 1.1018125438879192e-7
# Current loss after 26350 iterations: 1.1018125438870768e-7
# Current loss after 26400 iterations: 1.1018125438870345e-7
# Current loss after 26450 iterations: 1.1018125438870343e-7
# Current loss after 26500 iterations: 1.1031244962528043e-7
# Current loss after 26550 iterations: 1.1049006733674222e-7
# Current loss after 26600 iterations: 1.101817173706223e-7
# Current loss after 26650 iterations: 1.1018125868972902e-7
# Current loss after 26700 iterations: 1.1018125444888326e-7
# Current loss after 26750 iterations: 1.1018125438906355e-7
# Current loss after 26800 iterations: 1.1018125438870071e-7
# Current loss after 26850 iterations: 1.1018125438871018e-7
# Current loss after 26900 iterations: 1.1018125438870732e-7
# Current loss after 26950 iterations: 1.1018125487343845e-7
# Current loss after 27000 iterations: 1.1253566413372044e-7
# Current loss after 27050 iterations: 1.1019374841986734e-7
# Current loss after 27100 iterations: 1.101813196826929e-7
# Current loss after 27150 iterations: 1.1018125464841808e-7
# Current loss after 27200 iterations: 1.1018125438870143e-7
# Current loss after 27250 iterations: 1.1018125438872765e-7
# Current loss after 27300 iterations: 1.1018125438868496e-7
# Current loss after 27350 iterations: 1.1018125438870676e-7
# Current loss after 27400 iterations: 1.1018125438868741e-7
# Current loss after 27450 iterations: 1.1152467944127915e-7
# Current loss after 27500 iterations: 1.1039984554936068e-7
# Current loss after 27550 iterations: 1.101813487920294e-7
# Current loss after 27600 iterations: 1.1018126126644613e-7
# Current loss after 27650 iterations: 1.1018125440457487e-7
# Current loss after 27700 iterations: 1.1018125438872754e-7
# Current loss after 27750 iterations: 1.1018125438868379e-7
# Current loss after 27800 iterations: 1.1018125438869827e-7
# Current loss after 27850 iterations: 1.1018125438869443e-7
# Current loss after 27900 iterations: 1.1018125440842545e-7
# Current loss after 27950 iterations: 1.1158089328637917e-7
# Current loss after 28000 iterations: 1.1018480154280585e-7
# Current loss after 28050 iterations: 1.1018131875781488e-7
# Current loss after 28100 iterations: 1.1018125493112832e-7
# Current loss after 28150 iterations: 1.1018125439062786e-7
# Current loss after 28200 iterations: 1.101812543887125e-7
# Current loss after 28250 iterations: 1.1018125438869906e-7
# Current loss after 28300 iterations: 1.1018125438868216e-7
# Current loss after 28350 iterations: 1.1018125438869122e-7
# Current loss after 28400 iterations: 1.1018547069628734e-7
# Current loss after 28450 iterations: 1.1055756363396699e-7
# Current loss after 28500 iterations: 1.1018125438965566e-7
# Current loss after 28550 iterations: 1.101812645851031e-7
# Current loss after 28600 iterations: 1.1018125447257741e-7
# Current loss after 28650 iterations: 1.1018125438895391e-7
# Current loss after 28700 iterations: 1.1018125438868945e-7
# Current loss after 28750 iterations: 1.1018125438870472e-7
# Current loss after 28800 iterations: 1.1018125438869604e-7
# Current loss after 28850 iterations: 1.1018125438872074e-7
# Current loss after 28900 iterations: 1.2347329763666686e-7
# Current loss after 28950 iterations: 1.1021527612940165e-7
# Current loss after 29000 iterations: 1.1018160948583619e-7
# Current loss after 29050 iterations: 1.1018125452657924e-7
# Current loss after 29100 iterations: 1.101812544014794e-7
# Current loss after 29150 iterations: 1.1018125438879467e-7
# Current loss after 29200 iterations: 1.1018125438869308e-7
# Current loss after 29250 iterations: 1.1018125438870847e-7
# Current loss after 29300 iterations: 1.1018125438870284e-7
# Current loss after 29350 iterations: 1.101812543891008e-7
# Current loss after 29400 iterations: 1.139608284398781e-7
# Current loss after 29450 iterations: 1.1018484737030903e-7
# Current loss after 29500 iterations: 1.1018127482608052e-7
# Current loss after 29550 iterations: 1.1018125442785322e-7
# Current loss after 29600 iterations: 1.1018125438904588e-7
# Current loss after 29650 iterations: 1.1018125438873318e-7
# Current loss after 29700 iterations: 1.1018125438869309e-7
# Current loss after 29750 iterations: 1.1018125438870712e-7
# Current loss after 29800 iterations: 1.1018125438869981e-7
# Current loss after 29850 iterations: 1.1018125438870773e-7
# Current loss after 29900 iterations: 1.1018562714694285e-7
# Current loss after 29950 iterations: 1.1068252555899325e-7
# Current loss after 30000 iterations: 1.1018374317748155e-7
# Current loss after 30050 iterations: 1.1018126296901025e-7
# Current loss after 30100 iterations: 1.1018125442018282e-7
# Current loss after 30150 iterations: 1.1018125438907502e-7
# Current loss after 30200 iterations: 1.1018125438871225e-7
# Current loss after 30250 iterations: 1.1018125438869963e-7
# Current loss after 30300 iterations: 1.1018125438870163e-7
# Current loss after 30350 iterations: 1.1018125438870511e-7
# Current loss after 30400 iterations: 1.1018238872045395e-7
# Current loss after 30450 iterations: 1.1018136276932026e-7
# Current loss after 30500 iterations: 1.101812852716037e-7
# Current loss after 30550 iterations: 1.1018125438869952e-7
# Current loss after 30600 iterations: 1.1018125438949759e-7
# Current loss after 30650 iterations: 1.1018125438900992e-7
# Current loss after 30700 iterations: 1.1018125438871023e-7
# Current loss after 30750 iterations: 1.101812543887181e-7
# Current loss after 30800 iterations: 1.1018125438870097e-7
# Current loss after 30850 iterations: 1.1018125438871015e-7
# Current loss after 30900 iterations: 1.1027840897599705e-7
# Current loss after 30950 iterations: 1.105272552917411e-7
# Current loss after 31000 iterations: 1.1018144333817125e-7
# Current loss after 31050 iterations: 1.1018126064426308e-7
# Current loss after 31100 iterations: 1.1018125442208551e-7
# Current loss after 31150 iterations: 1.1018125438906254e-7
# Current loss after 31200 iterations: 1.101812543887045e-7
# Current loss after 31250 iterations: 1.1018125438870397e-7
# Current loss after 31300 iterations: 1.1018125438869146e-7
# Current loss after 31350 iterations: 1.10181254389296e-7
# Current loss after 31400 iterations: 1.1800054001547573e-7
# Current loss after 31450 iterations: 1.102263991116107e-7
# Current loss after 31500 iterations: 1.1018135235645757e-7
# Current loss after 31550 iterations: 1.1018125439126544e-7
# Current loss after 31600 iterations: 1.1018125438941576e-7
# Current loss after 31650 iterations: 1.1018125438873898e-7
# Current loss after 31700 iterations: 1.1018125438869257e-7
# Current loss after 31750 iterations: 1.101812543886975e-7
# Current loss after 31800 iterations: 1.1018125438869505e-7
# Current loss after 31850 iterations: 1.1018125439018863e-7
# Current loss after 31900 iterations: 1.1415876653863858e-7
# Current loss after 31950 iterations: 1.1021225609437438e-7
# Current loss after 32000 iterations: 1.1018126659907856e-7
# Current loss after 32050 iterations: 1.1018125534485003e-7
# Current loss after 32100 iterations: 1.1018125438871497e-7
# Current loss after 32150 iterations: 1.1018125438873102e-7
# Current loss after 32200 iterations: 1.1018125438869455e-7
# Current loss after 32250 iterations: 1.101812543887208e-7
# Current loss after 32300 iterations: 1.1018125438870752e-7
# Current loss after 32350 iterations: 1.1018125438873033e-7
# Current loss after 32400 iterations: 1.101812543887309e-7
# Current loss after 32450 iterations: 1.243088461094481e-7
# Current loss after 32500 iterations: 1.1022901522047372e-7
# Current loss after 32550 iterations: 1.1018171777104155e-7
# Current loss after 32600 iterations: 1.1018125541204369e-7
# Current loss after 32650 iterations: 1.1018125438897487e-7
# Current loss after 32700 iterations: 1.101812543887251e-7
# Current loss after 32750 iterations: 1.1018125438870364e-7
# Current loss after 32800 iterations: 1.1018125438871842e-7
# Current loss after 32850 iterations: 1.1018125438869913e-7
# Current loss after 32900 iterations: 1.1018125438869428e-7
# Current loss after 32950 iterations: 1.101812547188953e-7
# Current loss after 33000 iterations: 1.1039362147288698e-7
# Current loss after 33050 iterations: 1.1018999350840895e-7
# Current loss after 33100 iterations: 1.1018127448800909e-7
# Current loss after 33150 iterations: 1.1018125476075529e-7
# Current loss after 33200 iterations: 1.101812543896235e-7
# Current loss after 33250 iterations: 1.1018125438868974e-7
# Current loss after 33300 iterations: 1.1018125438869858e-7
# Current loss after 33350 iterations: 1.1018125438870241e-7
# Current loss after 33400 iterations: 1.1018125438870676e-7
# Current loss after 33450 iterations: 1.1018125439021877e-7
# Current loss after 33500 iterations: 1.1330537111762227e-7
# Current loss after 33550 iterations: 1.1021127605807908e-7
# Current loss after 33600 iterations: 1.1018134967175704e-7
# Current loss after 33650 iterations: 1.1018125463077287e-7
# Current loss after 33700 iterations: 1.1018125439505539e-7
# Current loss after 33750 iterations: 1.1018125438875136e-7
# Current loss after 33800 iterations: 1.1018125438871742e-7
# Current loss after 33850 iterations: 1.1018125438871223e-7
# Current loss after 33900 iterations: 1.1018125438871129e-7
# Current loss after 33950 iterations: 1.1018125462574505e-7
# Current loss after 34000 iterations: 1.1243267250483254e-7
# Current loss after 34050 iterations: 1.1019251737002602e-7
# Current loss after 34100 iterations: 1.1018133622838164e-7
# Current loss after 34150 iterations: 1.1018125487791408e-7
# Current loss after 34200 iterations: 1.1018125439125184e-7
# Current loss after 34250 iterations: 1.1018125438871098e-7
# Current loss after 34300 iterations: 1.1018125438869791e-7
# Current loss after 34350 iterations: 1.1018125438868706e-7
# Current loss after 34400 iterations: 1.1018125438869968e-7
# Current loss after 34450 iterations: 1.1018400736111696e-7
# Current loss after 34500 iterations: 1.1046907826634841e-7
# Current loss after 34550 iterations: 1.1018139724941094e-7
# Current loss after 34600 iterations: 1.1018125518710418e-7
# Current loss after 34650 iterations: 1.1018125444988896e-7
# Current loss after 34700 iterations: 1.1018125438917749e-7
# Current loss after 34750 iterations: 1.1018125438869832e-7
# Current loss after 34800 iterations: 1.1018125438871653e-7
# Current loss after 34850 iterations: 1.10181254388707e-7
# Current loss after 34900 iterations: 1.1018125438867995e-7
# Current loss after 34950 iterations: 1.3417574748877084e-7
# Current loss after 35000 iterations: 1.1030038702366731e-7
# Current loss after 35050 iterations: 1.1018126804111799e-7
# Current loss after 35100 iterations: 1.1018125880816534e-7
# Current loss after 35150 iterations: 1.1018125440538958e-7
# Current loss after 35200 iterations: 1.1018125438880097e-7
# Current loss after 35250 iterations: 1.1018125438868614e-7
# Current loss after 35300 iterations: 1.1018125438871112e-7
# Current loss after 35350 iterations: 1.1018125438872054e-7
# Current loss after 35400 iterations: 1.101812546854676e-7
# Current loss after 35450 iterations: 1.125647684976519e-7
# Current loss after 35500 iterations: 1.1019086545955849e-7
# Current loss after 35550 iterations: 1.1018131566499598e-7
# Current loss after 35600 iterations: 1.1018125470867563e-7
# Current loss after 35650 iterations: 1.1018125438898338e-7
# Current loss after 35700 iterations: 1.10181254388717e-7
# Current loss after 35750 iterations: 1.101812543886961e-7
# Current loss after 35800 iterations: 1.1018125438871472e-7
# Current loss after 35850 iterations: 1.1018125438872847e-7
# Current loss after 35900 iterations: 1.1021236202740783e-7
# Current loss after 35950 iterations: 1.1030828801492325e-7
# Current loss after 36000 iterations: 1.1018127294251355e-7
# Current loss after 36050 iterations: 1.1018125924699744e-7
# Current loss after 36100 iterations: 1.101812544639057e-7
# Current loss after 36150 iterations: 1.1018125438874115e-7
# Current loss after 36200 iterations: 1.1018125438870707e-7
# Current loss after 36250 iterations: 1.1018125438869793e-7
# Current loss after 36300 iterations: 1.1018125438869518e-7
# Current loss after 36350 iterations: 1.1018125438870662e-7
# Current loss after 36400 iterations: 1.1018130442589205e-7
# Current loss after 36450 iterations: 1.1024718878047522e-7
# Current loss after 36500 iterations: 1.1018735270932748e-7
# Current loss after 36550 iterations: 1.1018127722353999e-7
# Current loss after 36600 iterations: 1.101812544061726e-7
# Current loss after 36650 iterations: 1.101812543887657e-7
# Current loss after 36700 iterations: 1.1018125438871276e-7
# Current loss after 36750 iterations: 1.1018125438868234e-7
# Current loss after 36800 iterations: 1.1018125438872115e-7
# Current loss after 36850 iterations: 1.1018125438871609e-7
# Current loss after 36900 iterations: 1.1018125438870327e-7
# Current loss after 36950 iterations: 1.1018125438870033e-7
# Current loss after 37000 iterations: 1.101812546392841e-7
# Current loss after 37050 iterations: 1.1254025300812497e-7
# Current loss after 37100 iterations: 1.1019502231244012e-7
# Current loss after 37150 iterations: 1.1018127544762274e-7
# Current loss after 37200 iterations: 1.1018125467427221e-7
# Current loss after 37250 iterations: 1.1018125438905585e-7
# Current loss after 37300 iterations: 1.1018125438872016e-7
# Current loss after 37350 iterations: 1.10181254388705e-7
# Current loss after 37400 iterations: 1.1018125438872632e-7
# Current loss after 37450 iterations: 1.1018125438868973e-7
# Current loss after 37500 iterations: 1.1018125438869869e-7
# Current loss after 37550 iterations: 1.1018125438870364e-7
# Current loss after 37600 iterations: 1.101812543887014e-7
# Current loss after 37650 iterations: 1.2796628463107564e-7
# Current loss after 37700 iterations: 1.1018125474550675e-7
# Current loss after 37750 iterations: 1.1018135033164554e-7
# Current loss after 37800 iterations: 1.1018125656032928e-7
# Current loss after 37850 iterations: 1.1018125440451743e-7
# Current loss after 37900 iterations: 1.1018125438880008e-7
# Current loss after 37950 iterations: 1.1018125438871075e-7
# Current loss after 38000 iterations: 1.1018125438871225e-7
# Current loss after 38050 iterations: 1.1018125438870462e-7
# Current loss after 38100 iterations: 1.101812543886932e-7
# Current loss after 38150 iterations: 1.1018125542506481e-7
# Current loss after 38200 iterations: 1.1216056013451558e-7
# Current loss after 38250 iterations: 1.1018333398876904e-7
# Current loss after 38300 iterations: 1.101812666178706e-7
# Current loss after 38350 iterations: 1.1018125472690515e-7
# Current loss after 38400 iterations: 1.1018125438964018e-7
# Current loss after 38450 iterations: 1.1018125438872496e-7
# Current loss after 38500 iterations: 1.1018125438869276e-7
# Current loss after 38550 iterations: 1.1018125438868843e-7
# Current loss after 38600 iterations: 1.1018125438871252e-7
# Current loss after 38650 iterations: 1.101812543887061e-7
# Current loss after 38700 iterations: 1.418564985686925e-7
# Current loss after 38750 iterations: 1.1028825285678176e-7
# Current loss after 38800 iterations: 1.1018183666457396e-7
# Current loss after 38850 iterations: 1.101812581570654e-7
# Current loss after 38900 iterations: 1.1018125440937448e-7
# Current loss after 38950 iterations: 1.1018125438874722e-7
# Current loss after 39000 iterations: 1.1018125438871982e-7
# Current loss after 39050 iterations: 1.101812543887002e-7
# Current loss after 39100 iterations: 1.1018125438870545e-7
# Current loss after 39150 iterations: 1.1018125438868928e-7
# Current loss after 39200 iterations: 1.101813448612345e-7
# Current loss after 39250 iterations: 1.1123516737075684e-7
# Current loss after 39300 iterations: 1.1018195381329127e-7
# Current loss after 39350 iterations: 1.1018126198732308e-7
# Current loss after 39400 iterations: 1.1018125456148801e-7
# Current loss after 39450 iterations: 1.1018125438920319e-7
# Current loss after 39500 iterations: 1.1018125438872749e-7
# Current loss after 39550 iterations: 1.1018125438869703e-7
# Current loss after 39600 iterations: 1.1018125438870719e-7
# Current loss after 39650 iterations: 1.101812543887034e-7
# Current loss after 39700 iterations: 1.1018125438870668e-7
# Current loss after 39750 iterations: 1.179291150132172e-7
# Current loss after 39800 iterations: 1.1029041751081675e-7
# Current loss after 39850 iterations: 1.1018125468008562e-7
# Current loss after 39900 iterations: 1.1018125932471339e-7
# Current loss after 39950 iterations: 1.101812544177616e-7
# Current loss after 40000 iterations: 1.1018125438877508e-7
# Current loss after 40050 iterations: 1.1018125438868363e-7
# Current loss after 40100 iterations: 1.1018125438868879e-7
# Current loss after 40150 iterations: 1.1018125438870948e-7
# Current loss after 40200 iterations: 1.1018125438870488e-7
# Current loss after 40250 iterations: 1.1018125467306481e-7
# Current loss after 40300 iterations: 1.1205729519793932e-7
# Current loss after 40350 iterations: 1.1018265754009854e-7
# Current loss after 40400 iterations: 1.1018129823372049e-7
# Current loss after 40450 iterations: 1.1018125479959061e-7
# Current loss after 40500 iterations: 1.101812543894801e-7
# Current loss after 40550 iterations: 1.1018125438871712e-7
# Current loss after 40600 iterations: 1.1018125438869889e-7
# Current loss after 40650 iterations: 1.1018125438869983e-7
# Current loss after 40700 iterations: 1.1018125438872234e-7
# Current loss after 40750 iterations: 1.1018125472744224e-7
# Current loss after 40800 iterations: 1.1241226196420903e-7
# Current loss after 40850 iterations: 1.1019070811303485e-7
# Current loss after 40900 iterations: 1.1018126151685622e-7
# Current loss after 40950 iterations: 1.1018125441473548e-7
# Current loss after 41000 iterations: 1.1018125438895939e-7
# Current loss after 41050 iterations: 1.1018125438869784e-7
# Current loss after 41100 iterations: 1.1018125438871832e-7
# Current loss after 41150 iterations: 1.1018125438869684e-7
# Current loss after 41200 iterations: 1.1018125438867615e-7
# Current loss after 41250 iterations: 1.101815540479431e-7
# Current loss after 41300 iterations: 1.1054022653779899e-7
# Current loss after 41350 iterations: 1.1018146363097287e-7
# Current loss after 41400 iterations: 1.1018127324783255e-7
# Current loss after 41450 iterations: 1.101812545072008e-7
# Current loss after 41500 iterations: 1.1018125438903393e-7
# Current loss after 41550 iterations: 1.1018125438871484e-7
# Current loss after 41600 iterations: 1.101812543887196e-7
# Current loss after 41650 iterations: 1.1018125438869386e-7
# Current loss after 41700 iterations: 1.1018125438872814e-7
# Current loss after 41750 iterations: 1.101858387945609e-7
# Current loss after 41800 iterations: 1.1020492008877578e-7
# Current loss after 41850 iterations: 1.1018170120002965e-7
# Current loss after 41900 iterations: 1.1018125480339744e-7
# Current loss after 41950 iterations: 1.1018125440019866e-7
# Current loss after 42000 iterations: 1.1018125438878317e-7
# Current loss after 42050 iterations: 1.1018125438871428e-7
# Current loss after 42100 iterations: 1.101812543886847e-7
# Current loss after 42150 iterations: 1.1018125438870258e-7
# Current loss after 42200 iterations: 1.1018125439108886e-7
# Current loss after 42250 iterations: 1.1623745886784197e-7
# Current loss after 42300 iterations: 1.1021408956744453e-7
# Current loss after 42350 iterations: 1.1018126262457361e-7
# Current loss after 42400 iterations: 1.1018125508518105e-7
# Current loss after 42450 iterations: 1.101812543949939e-7
# Current loss after 42500 iterations: 1.1018125438874667e-7
# Current loss after 42550 iterations: 1.1018125438869553e-7
# Current loss after 42600 iterations: 1.1018125438871603e-7
# Current loss after 42650 iterations: 1.1018125438870274e-7
# Current loss after 42700 iterations: 1.101812552258965e-7
# Current loss after 42750 iterations: 1.1072332719080942e-7
# Current loss after 42800 iterations: 1.1018867950312523e-7
# Current loss after 42850 iterations: 1.1018129930759116e-7
# Current loss after 42900 iterations: 1.101812547243232e-7
# Current loss after 42950 iterations: 1.1018125439070371e-7
# Current loss after 43000 iterations: 1.1018125438870529e-7
# Current loss after 43050 iterations: 1.1018125438870594e-7
# Current loss after 43100 iterations: 1.101812543887028e-7
# Current loss after 43150 iterations: 1.1018125438869297e-7
# Current loss after 43200 iterations: 1.108949900783213e-7
# Current loss after 43250 iterations: 1.1024563976338498e-7
# Current loss after 43300 iterations: 1.1018237182980583e-7
# Current loss after 43350 iterations: 1.1018125596341045e-7
# Current loss after 43400 iterations: 1.1018125443601845e-7
# Current loss after 43450 iterations: 1.1018125438894207e-7
# Current loss after 43500 iterations: 1.1018125438870963e-7
# Current loss after 43550 iterations: 1.101812543887151e-7
# Current loss after 43600 iterations: 1.1018125438869661e-7
# Current loss after 43650 iterations: 1.1018125443240565e-7
# Current loss after 43700 iterations: 1.1393889500928628e-7
# Current loss after 43750 iterations: 1.1019572794817696e-7
# Current loss after 43800 iterations: 1.1018133840765289e-7
# Current loss after 43850 iterations: 1.1018125477382686e-7
# Current loss after 43900 iterations: 1.1018125438878976e-7
# Current loss after 43950 iterations: 1.1018125438872893e-7
# Current loss after 44000 iterations: 1.1018125438871781e-7
# Current loss after 44050 iterations: 1.1018125438867585e-7
# Current loss after 44100 iterations: 1.101812543886988e-7
# Current loss after 44150 iterations: 1.1117881647037813e-7
# Current loss after 44200 iterations: 1.1024060185715425e-7
# Current loss after 44250 iterations: 1.1018258786782652e-7
# Current loss after 44300 iterations: 1.1018125692767849e-7
# Current loss after 44350 iterations: 1.1018125438888243e-7
# Current loss after 44400 iterations: 1.1018125438873723e-7
# Current loss after 44450 iterations: 1.1018125438873077e-7
# Current loss after 44500 iterations: 1.101812543886938e-7
# Current loss after 44550 iterations: 1.101812543886985e-7
# Current loss after 44600 iterations: 1.1018128838722659e-7
# Current loss after 44650 iterations: 1.1034022073333088e-7
# Current loss after 44700 iterations: 1.1018696021571955e-7
# Current loss after 44750 iterations: 1.1018126256147809e-7
# Current loss after 44800 iterations: 1.1018125459224027e-7
# Current loss after 44850 iterations: 1.1018125438934752e-7
# Current loss after 44900 iterations: 1.101812543886977e-7
# Current loss after 44950 iterations: 1.1018125438870924e-7
# Current loss after 45000 iterations: 1.1018125438870741e-7
# Current loss after 45050 iterations: 1.1018125447921394e-7
# Current loss after 45100 iterations: 1.1358088882470926e-7
# Current loss after 45150 iterations: 1.1018291791554673e-7
# Current loss after 45200 iterations: 1.1018129263902811e-7
# Current loss after 45250 iterations: 1.1018125494825548e-7
# Current loss after 45300 iterations: 1.1018125439012912e-7
# Current loss after 45350 iterations: 1.1018125438871294e-7
# Current loss after 45400 iterations: 1.1018125438872409e-7
# Current loss after 45450 iterations: 1.1018125438870225e-7
# Current loss after 45500 iterations: 1.1018125439065019e-7
# Current loss after 45550 iterations: 1.1496534478551011e-7
# Current loss after 45600 iterations: 1.1019999321919841e-7
# Current loss after 45650 iterations: 1.1018125803350957e-7
# Current loss after 45700 iterations: 1.1018125498629733e-7
# Current loss after 45750 iterations: 1.1018125439314893e-7
# Current loss after 45800 iterations: 1.101812543887554e-7
# Current loss after 45850 iterations: 1.1018125438871252e-7
# Current loss after 45900 iterations: 1.1018125438870655e-7
# Current loss after 45950 iterations: 1.1018125438870324e-7
# Current loss after 46000 iterations: 1.4092681047984755e-7
# Current loss after 46050 iterations: 1.1019143897517578e-7
# Current loss after 46100 iterations: 1.1018171889472918e-7
# Current loss after 46150 iterations: 1.1018125775633837e-7
# Current loss after 46200 iterations: 1.1018125439187087e-7
# Current loss after 46250 iterations: 1.1018125438876697e-7
# Current loss after 46300 iterations: 1.1018125438868844e-7
# Current loss after 46350 iterations: 1.1018125438869366e-7
# Current loss after 46400 iterations: 1.1018125438869215e-7
# Current loss after 46450 iterations: 1.101812543894356e-7
# Current loss after 46500 iterations: 1.1697280245133723e-7
# Current loss after 46550 iterations: 1.1022526693058091e-7
# Current loss after 46600 iterations: 1.1018140340305354e-7
# Current loss after 46650 iterations: 1.1018125459294998e-7
# Current loss after 46700 iterations: 1.1018125438984525e-7
# Current loss after 46750 iterations: 1.1018125438876608e-7
# Current loss after 46800 iterations: 1.1018125438872307e-7
# Current loss after 46850 iterations: 1.1018125438871084e-7
# Current loss after 46900 iterations: 1.1018125438869073e-7
# Current loss after 46950 iterations: 1.1018181589977646e-7
# Current loss after 47000 iterations: 1.109251850672395e-7
# Current loss after 47050 iterations: 1.101819076878619e-7
# Current loss after 47100 iterations: 1.1018126024945578e-7
# Current loss after 47150 iterations: 1.1018125452417465e-7
# Current loss after 47200 iterations: 1.101812543888884e-7
# Current loss after 47250 iterations: 1.1018125438869968e-7
# Current loss after 47300 iterations: 1.1018125438869932e-7
# Current loss after 47350 iterations: 1.1018125438869629e-7
# Current loss after 47400 iterations: 1.1018125438889443e-7
# Current loss after 47450 iterations: 1.1035991940707993e-7
# Current loss after 47500 iterations: 1.1021335756984297e-7
# Current loss after 47550 iterations: 1.1018127513786518e-7
# Current loss after 47600 iterations: 1.1018125447352013e-7
# Current loss after 47650 iterations: 1.1018125438908466e-7
# Current loss after 47700 iterations: 1.1018125438873661e-7
# Current loss after 47750 iterations: 1.1018125438871019e-7
# Current loss after 47800 iterations: 1.1018125438871059e-7
# Current loss after 47850 iterations: 1.101812543886838e-7
# Current loss after 47900 iterations: 1.1018321706560173e-7
# Current loss after 47950 iterations: 1.1032503318797742e-7
# Current loss after 48000 iterations: 1.1018394138553873e-7
# Current loss after 48050 iterations: 1.1018125752749131e-7
# Current loss after 48100 iterations: 1.1018125445691953e-7
# Current loss after 48150 iterations: 1.1018125438935812e-7
# Current loss after 48200 iterations: 1.1018125438870366e-7
# Current loss after 48250 iterations: 1.1018125438869018e-7
# Current loss after 48300 iterations: 1.1018125438870971e-7
# Current loss after 48350 iterations: 1.1018125440487576e-7
# Current loss after 48400 iterations: 1.102268738399046e-7
# Current loss after 48450 iterations: 1.1018359845492234e-7
# Current loss after 48500 iterations: 1.1018125722695332e-7
# Current loss after 48550 iterations: 1.1018125440257603e-7
# Current loss after 48600 iterations: 1.1018125439051424e-7
# Current loss after 48650 iterations: 1.1018125438870449e-7
# Current loss after 48700 iterations: 1.1018125438868773e-7
# Current loss after 48750 iterations: 1.1018125438870337e-7
# Current loss after 48800 iterations: 1.1018125438872562e-7
# Current loss after 48850 iterations: 1.1025189862727288e-7
# Current loss after 48900 iterations: 1.1042163169186757e-7
# Current loss after 48950 iterations: 1.101817159981427e-7
# Current loss after 49000 iterations: 1.1018126446052263e-7
# Current loss after 49050 iterations: 1.1018125440665464e-7
# Current loss after 49100 iterations: 1.101812543887047e-7
# Current loss after 49150 iterations: 1.1018125438870523e-7
# Current loss after 49200 iterations: 1.1018125438870343e-7
# Current loss after 49250 iterations: 1.1018125438869935e-7
# Current loss after 49300 iterations: 1.10181254414783e-7
# Current loss after 49350 iterations: 1.1056267220320327e-7
# Current loss after 49400 iterations: 1.1018810599873017e-7
# Current loss after 49450 iterations: 1.1018133950041172e-7
# Current loss after 49500 iterations: 1.1018125514162489e-7
# Current loss after 49550 iterations: 1.1018125438944348e-7
# Current loss after 49600 iterations: 1.1018125438873134e-7
# Current loss after 49650 iterations: 1.1018125438870169e-7
# Current loss after 49700 iterations: 1.101812543886902e-7
# Current loss after 49750 iterations: 1.1018125438870053e-7
# Current loss after 49800 iterations: 1.3398476999067073e-7
# Current loss after 49850 iterations: 1.1020018634053055e-7
# Current loss after 49900 iterations: 1.1018127055705172e-7
# Current loss after 49950 iterations: 1.101812543933311e-7
# Current loss after 50000 iterations: 1.1018125439264511e-7
# retcode: Default
# u: 2-element Vector{Float64}:
#   0.10202966301193382
#  -0.0037530782220365428

# %%
fig = Figure()
ax = Axis(fig[1, 1], xlabel = L"iter", ylabel = L"losses")
lines!(ax,log10.(losses),color=:black,label="losses")
axislegend(ax,position=:lt)
fig

# %%
sol.u
# Out:
# 2-element Vector{Float64}:
#   0.10202966301193382
#  -0.0037530782220365428

# %%
    C=(sol.u[1].+sol.u[2]*xdata)
    C[1]=0.0
    C[n]=0.0
    prob=LinearProblem(A,C)
    ymodel=LinearSolve.solve(prob)
# Out:
# retcode: Success
# u: 21-element Vector{Float64}:
#   3.6748382115092687e-16
#  -0.0037874982794743
#  -0.007282516553402144
#  -0.01045057377382164
#  -0.013260458503306347
#  -0.015684541029339173
#  -0.017699049661437545
#  -0.019284308448058233
#  -0.020424933936112784
#  -0.021109989005498406
#   ⋮
#  -0.020391032753185618
#  -0.019236228895698294
#  -0.01764008734383496
#  -0.015619038647892
#  -0.013193762429606603
#  -0.010388980585939374
#  -0.007233210070104745
#  -0.0037584777220388155
#   0.0

# %%
fig = Figure()
ax = Axis(fig[1, 1], xlabel = L"x", ylabel = L"T(x)")
scatter!(ax,xdata,ydata,color=:black,label="data")
lines!(ax,xdata,ymodel,color=:black,label="Model")
axislegend(ax,position=:lt)
fig

# %%
fig = Figure()
ax = Axis(fig[1, 1], xlabel = L"x", ylabel = L"w(x)")
scatter!(ax,xdata[2:end-1],C[2:end-1],color=:black,label="Predicted Loading")
axislegend(ax,position=:lt)
fig

# %%
sol.u
# Out:
# 2-element Vector{Float64}:
#   0.10202966301193382
#  -0.0037530782220365428

# %% [markdown]
# ---

# %% [markdown]
# **Class Exercise:** Now try to model the data using simple polynomial.
#
# $f_{model}(\vec{a},x)=a_0x+a_1x+a_2x^2+a_3x^3+...$
#
# What are the values of $\vec{a}$ that best fit this data?
